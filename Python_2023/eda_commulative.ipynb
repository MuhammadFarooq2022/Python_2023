# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_usa = pd.read_csv("./US_Covid19_Data_Sets/us.csv")

# %%
df_usa.head()
# Out:
#          date  cases  deaths
# 0  2020-01-21      1       0
# 1  2020-01-22      1       0
# 2  2020-01-23      1       0
# 3  2020-01-24      2       0
# 4  2020-01-25      3       0

# %%
df_usa.tail()
# Out:
#             date      cases   deaths
# 1115  2023-02-09  102555293  1120505
# 1116  2023-02-10  102569435  1120667
# 1117  2023-02-11  102571337  1120678
# 1118  2023-02-12  102574464  1120691
# 1119  2023-02-13  102598932  1120904

# %%
df_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1120 non-null   object
#  1   cases   1120 non-null   int64
#  2   deaths  1120 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 26.4+ KB

# %%
sns.pairplot(df_usa)

# %%
df_usa.describe()
# Out:
#               cases        deaths
# count  1.120000e+03  1.120000e+03
# mean   4.570661e+07  6.131444e+05
# std    3.582277e+07  3.738845e+05
# min    1.000000e+00  0.000000e+00
# 25%    8.833784e+06  2.264382e+05
# 50%    3.525278e+07  6.137745e+05
# 75%    8.190838e+07  9.966880e+05
# max    1.025989e+08  1.120904e+06

# %%
sns.lineplot(df_usa, x="date", y="cases")
# Out:
# <AxesSubplot:xlabel='date', ylabel='cases'>

# %%
sns.lineplot(df_usa, x="date", y="deaths")
# Out:
# <AxesSubplot:xlabel='date', ylabel='deaths'>

# %%
df_usa.isnull().sum()
# Out:
# date      0
# cases     0
# deaths    0
# dtype: int64

# %%
sns.histplot(df_usa["deaths"])
# Out:
# <AxesSubplot:xlabel='deaths', ylabel='Count'>
